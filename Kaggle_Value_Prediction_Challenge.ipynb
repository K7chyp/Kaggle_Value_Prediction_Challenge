# %% [markdown]
# <a href="https://colab.research.google.com/github/K7chyp/Kaggle_Value_Prediction_Challenge/blob/main/Kaggle_Value_Prediction_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

train_df = pd.read_csv('/content/drive/MyDrive/csv/train.csv') 
test_df = pd.read_csv('/content/drive/MyDrive/csv/test.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys 
sys.path.append('/content/drive/MyDrive/module ')

# %%
train_df.head()
# Out:
#           ID      target  48df886f9  ...  fb36b89d9  7e293fbaf  9fc776466
# 0  000d6aaf2  38000000.0        0.0  ...          0          0          0
# 1  000fbd867    600000.0        0.0  ...          0          0          0
# 2  0027d6b71  10000000.0        0.0  ...          0          0          0
# 3  0028cbf45   2000000.0        0.0  ...          0          0          0
# 4  002a68644  14400000.0        0.0  ...          0          0          0
#
# [5 rows x 4993 columns]

# %%
from Exploration import Exploration

exp = Exploration(train_df, 
                  test_df)
exp.find_max_values()

# %%
from Visualisation import Visualisation
vis = Visualisation(train_df=train_df, 
                    test_df=test_df)
vis.plot_target()

# %%
vis.plot_target_hist()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from Preprocessing import Preprocessing
prep  = Preprocessing(train_df, 
                     test_df)
train, test = prep.prerproce_it()

# %%
train.head()
# Out:
#           ID      target  48df886f9  ...  fb36b89d9  7e293fbaf  9fc776466
# 0  000d6aaf2  38000000.0        0.0  ...          0          0          0
# 1  000fbd867    600000.0        0.0  ...          0          0          0
# 2  0027d6b71  10000000.0        0.0  ...          0          0          0
# 3  0028cbf45   2000000.0        0.0  ...          0          0          0
# 4  002a68644  14400000.0        0.0  ...          0          0          0
#
# [5 rows x 4737 columns]
